# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
from datetime import datetime

# %%
df= pd.read_csv ('Foston_In_RP_Pos.csv')
print(df)

# %%
df.describe()
# Out:
#               m/z    RT [min]  MS/MS Verified  Annot. DeltaMass [ppm]  \
# count  860.000000  860.000000             0.0              488.000000
# mean   276.638386    5.273799             NaN              742.020779
# std    128.212189    3.714071             NaN            11417.493498
# min     82.013610    0.808000             NaN          -102679.680000
# 25%    182.741658    1.166250             NaN               -2.802500
# 50%    265.014735    5.811000             NaN               -1.430000
# 75%    337.189687    8.241500             NaN               -0.857500
# max    786.163610   13.266000             NaN            97223.240000
#
#          Calc. MW   Area (Max.)      Blank 01      Blank 02  QC 01 RP Pos  \
# count  860.000000  8.600000e+02  8.600000e+02  8.600000e+02  8.600000e+02
# mean   275.525424  9.754217e+07  2.314968e+05  2.657895e+05  7.074664e+07
# std    127.738963  6.117056e+08  8.775931e+05  1.437825e+06  5.745626e+08
# ...

# %%
df2=pd.read_csv('FostonRP3min.csv')
print(df2)

# %%
df2.describe()
# Out:
#        precursor mass       RTMean           G1           G2           G3  \
# count     1156.000000  1156.000000  1156.000000  1156.000000  1156.000000
# mean       335.260298   408.143757     3.933391     3.544118     1.544118
# std        146.763171   219.802542     5.907796     6.000920     2.852924
# min         94.041400    43.070850     0.000000     0.000000     0.000000
# 25%        231.783500   230.034165     1.000000     0.000000     0.000000
# 50%        297.640000   447.042857     3.000000     2.000000     1.000000
# 75%        396.700000   572.247266     6.000000     6.000000     3.000000
# max        799.734000   851.969250    88.000000    90.000000    45.000000
#
#                 G4           G5           G6  Library_Class    MassDiff  ...  \
# count  1156.000000  1156.000000  1156.000000     141.000000  141.000000  ...
# mean      1.552768     1.453287     1.625433       2.503546    4.711277  ...
# ...

# %%
df.head()
# Out:
#          m/z  RT [min]                               Name  \
# 0   90.05474     0.946                         DL-Alanine
# 1  120.06517     0.953                       DL-Threonine
# 2  102.05466     0.962  1-Aminocyclopropane-1-carboxylate
# 3  162.07533     0.974                 2-Aminoadipic acid
# 4   96.04412     0.992                  2-Hydroxypyridine
#
#                                                 Tags      Formula  \
# 0  Confirmed ID (HIgh Confidence); Match Mass, MS...   C3 H7 N O2
# 1  Confirmed ID (HIgh Confidence); Match Mass, MS...   C4 H9 N O3
# 2  Confirmed ID (HIgh Confidence); Match Mass, MS...   C4 H7 N O2
# 3  Confirmed ID (HIgh Confidence); Match Mass, MS...  C6 H11 N O4
# 4  Confirmed ID (HIgh Confidence); Match Mass, MS...    C5 H5 N O
#
#    MS/MS Verified Annot. Source: mzCloud Search Annot. Source: mzVault Search  \
# 0             NaN               Not the top hit                    No results
# ...

# %%
df2.head()
# Out:
#    precursor mass      RTMean Adduct           Compound_Name Compound_Source  \
# 0         409.125  414.571000    NaN                     NaN             NaN
# 1         332.185  360.568000    NaN                     NaN             NaN
# 2         526.756   55.536667    NaN                     NaN             NaN
# 3         398.181  299.288500    M+H  Mycofactocin-1 reduced           Crude
# 4         212.164  425.569000    NaN                     NaN             NaN
#
#     Data_Collector      DefaultGroups  G1  G2  G3  ...  shared name  \
# 0              NaN                 G1   2   0   0  ...         1864
# 1              NaN                 G1   2   0   0  ...         1450
# 2              NaN           G1,G2,G6   3   4   0  ...         2222
# 3  Luis Pena-Ortiz                 G1   6   0   0  ...         1791
# 4              NaN  G1,G2,G3,G4,G5,G6   1   1   2  ...          306
#
#    SharedPeaks                                             Smiles  \
# ...
